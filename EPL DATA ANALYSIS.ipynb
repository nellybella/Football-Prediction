# %% [markdown]
# ## Import python libraries

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
import pkgutil
import encodings
import os

def all_encodings():
    modnames = set([modname for importer, modname, ispkg in pkgutil.walk_packages(
        path=[os.path.dirname(encodings.__file__)], prefix='')])
    aliases = set(encodings.aliases.aliases.values())
    return modnames.union(aliases)

text = b'\x96'
for enc in all_encodings():
    try:
        msg = text.decode(enc)
    except Exception:
        continue
    if msg == 'ñ':
        print('Decoding {t} with {enc} is {m}'.format(t=text, enc=enc, m=msg))
# Out:
# Decoding b'\x96' with mac_farsi is ñ
# Decoding b'\x96' with mac_turkish is ñ
# Decoding b'\x96' with mac_arabic is ñ
# Decoding b'\x96' with mac_croatian is ñ
# Decoding b'\x96' with mac_iceland is ñ
# Decoding b'\x96' with mac_roman is ñ
# Decoding b'\x96' with mac_romanian is ñ

# %%
data1 = pd.read_csv('output1.csv')

# %%
data2 = pd.read_csv('output2.csv')

# %%
data3 = pd.read_csv('output3.csv',encoding='ISO-8859-1')

# %%
data4 = pd.read_csv('output4.csv')

# %%
 #use ISO-8859-1 encoding

# %%
data5 = pd.read_csv('output5.csv',encoding='ISO-8859-1')

# %%
data1.head(3)
# Out:
#   Div      Date    HomeTeam        AwayTeam FTHG FTAG FTR HTHG HTAG HTR  ...  \
# 0  E0  16/08/14     Arsenal  Crystal Palace    2    1   H    1    1   D  ...
# 1  E0  16/08/14   Leicester         Everton    2    2   D    1    2   A  ...
# 2  E0  16/08/14  Man United         Swansea    1    2   A    0    1   A  ...
#
#   BbAv<2.5 BbAH BbAHh BbMxAHH BbAvAHH BbMxAHA BbAvAHA  PSCH  PSCD   PSCA
# 0      2.1   24  -1.5    1.81    1.78     2.2     2.1  1.29   5.9  12.75
# 1      1.8   22  0.25    1.88    1.85     2.1    2.02  3.11   3.4   2.47
# 2     2.13   25  -1.5    2.18    2.08    1.87    1.79  1.45  4.81   8.25
#
# [3 rows x 68 columns]

# %%
data2.head(3)
# Out:
#   Div      Date     HomeTeam     AwayTeam FTHG FTAG FTR HTHG HTAG HTR  ...  \
# 0  E0  08/08/15  Bournemouth  Aston Villa    0    1   A    0    0   D  ...
# 1  E0  08/08/15      Chelsea      Swansea    2    2   D    2    1   H  ...
# 2  E0  08/08/15      Everton      Watford    2    2   D    0    1   A  ...
#
#   BbAv<2.5 BbAH BbAHh BbMxAHH BbAvAHH BbMxAHA BbAvAHA  PSCH  PSCD   PSCA
# 0     1.79   26  -0.5    1.98    1.93    1.99    1.92  1.82  3.88    4.7
# 1     1.99   27  -1.5    2.24    2.16     1.8    1.73  1.37  5.04  10.88
# 2     1.96   26    -1    2.28    2.18    1.76    1.71  1.75  3.76   5.44
#
# [3 rows x 65 columns]

# %%
data3.head(3)
# Out:
#   Div      Date        HomeTeam   AwayTeam FTHG FTAG FTR HTHG HTAG HTR  ...  \
# 0  E0  13/08/16         Burnley    Swansea    0    1   A    0    0   D  ...
# 1  E0  13/08/16  Crystal Palace  West Brom    0    1   A    0    0   D  ...
# 2  E0  13/08/16         Everton  Tottenham    1    1   D    1    0   H  ...
#
#   BbAv<2.5 BbAH  BbAHh BbMxAHH BbAvAHH BbMxAHA BbAvAHA  PSCH  PSCD  PSCA
# 0     1.61   32  -0.25    2.13    2.06    1.86    1.81  2.79  3.16  2.89
# 1     1.52   33   -0.5    2.07       2     1.9    1.85  2.25  3.15  3.86
# 2     1.77   32   0.25    1.91    1.85    2.09       2  3.64  3.54  2.16
#
# [3 rows x 65 columns]

# %%
data4.head(3)
# Out:
#   Div      Date  HomeTeam   AwayTeam FTHG FTAG FTR HTHG HTAG HTR  ...  \
# 0  E0  11/08/17   Arsenal  Leicester    4    3   H    2    2   D  ...
# 1  E0  12/08/17  Brighton   Man City    0    2   A    0    0   D  ...
# 2  E0  12/08/17   Chelsea    Burnley    2    3   A    0    3   A  ...
#
#   BbAv<2.5 BbAH  BbAHh BbMxAHH BbAvAHH BbMxAHA BbAvAHA   PSCH  PSCD   PSCA
# 0     2.32   21     -1    1.91    1.85     2.1    2.02   1.49  4.73   7.25
# 1     2.27   20    1.5    1.95    1.91    2.01    1.96  11.75  6.15   1.29
# 2     2.23   20  -1.75    2.03    1.97    1.95     1.9   1.33   5.4  12.25
#
# [3 rows x 65 columns]

# %%
data5.head(3)
# Out:
#   Div        Date     HomeTeam        AwayTeam FTHG FTAG FTR HTHG HTAG HTR  \
# 0  E0  10/08/2018   Man United       Leicester    2    1   H    1    0   H
# 1  E0  11/08/2018  Bournemouth         Cardiff    2    0   H    1    0   H
# 2  E0  11/08/2018       Fulham  Crystal Palace    0    2   A    0    1   A
#
#    ... BbAv<2.5 BbAH  BbAHh BbMxAHH BbAvAHH BbMxAHA BbAvAHA  PSCH  PSCD  PSCA
# 0  ...     1.79   17  -0.75    1.75     1.7    2.29    2.21  1.55  4.07  7.69
# 1  ...     1.83   20  -0.75     2.2    2.13     1.8    1.75  1.88  3.61   4.7
# 2  ...     1.87   22  -0.25    2.18    2.11    1.81    1.77  2.62  3.38   2.9
#
# [3 rows x 62 columns]

# %%
data1.shape
# Out:
# (8187, 68)

# %%
data2.shape
# Out:
# (7784, 65)

# %%
data3.shape
# Out:
# (2592, 65)

# %%
data4.shape
# Out:
# (2592, 65)

# %%
data5.shape
# Out:
# (2582, 62)

# %%
data1.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD',
#        'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'PSH', 'PSD', 'PSA',
#        'WHH', 'WHD', 'WHA', 'SJH', 'SJD', 'SJA', 'VCH', 'VCD', 'VCA', 'Bb1X2',
#        'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD', 'BbMxA', 'BbAvA', 'BbOU',
#        'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5', 'BbAv<2.5', 'BbAH', 'BbAHh',
#        'BbMxAHH', 'BbAvAHH', 'BbMxAHA', 'BbAvAHA', 'PSCH', 'PSCD', 'PSCA'],
#       dtype='object')

# %%
f = open("notes.txt", "r")
print(f.read())
# Out:
# Notes for Football Data
#
# All data is in csv format, ready for use within standard spreadsheet applications. Please note that some abbreviations are no longer in use (in particular odds from specific bookmakers no longer used) and refer to data collected in earlier seasons. For a current list of what bookmakers are included in the dataset please visit http://www.football-data.co.uk/matches.php
#
# Key to results data:
#
# Div = League Division
# Date = Match Date (dd/mm/yy)
# HomeTeam = Home Team
# AwayTeam = Away Team
# FTHG and HG = Full Time Home Team Goals
# FTAG and AG = Full Time Away Team Goals
# FTR and Res = Full Time Result (H=Home Win, D=Draw, A=Away Win)
# HTHG = Half Time Home Team Goals
# HTAG = Half Time Away Team Goals
# HTR = Half Time Result (H=Home Win, D=Draw, A=Away Win)
#
# Match Statistics (where available)
# Attendance = Crowd Attendance
# Referee = Match Referee
# HS = Home Team Shots
# AS = Away Team Shots
# HST = Home Team Shots on Target
# ...

# %%
import glob
import pandas as pd
df = pd.concat([pd.read_csv(f, encoding='ISO-8859-1') for f in glob.glob('output*.csv')],ignore_index=True)

# %%
pwd
# Out:
# 'C:\\Users\\NELLY PC\\Desktop\\Data\\final'

# %%
df.shape
# Out:
# (23737, 68)

# %%
df.ndim
# Out:
# 2

# %%
df['AwayTeam'].nunique()
# Out:
# 131

# %%
df['HomeTeam'].nunique()
# Out:
# 131

# %%
df.describe()
# Out:
#            AC     AF     AR     AS    AST     AY AwayTeam  B365A  B365D  \
# count   23679  23700  23685  23702  23702  23679    23703  23681  23681
# unique    101     56     49     36     19     90      131    247    275
# top         4     11      0     10      3      1      QPR      3    3.4
# freq     3566   2459  20001   2193   4294   6807      214    960   4914
#
#         B365H  ... Referee   SJA   SJD   SJH    VCA    VCD    VCH    WHA  \
# count   23686  ...   23696  1342  1342  1342  23703  23703  23703  23698
# unique    164  ...     182    52    19    50    139    505    473    260
# top       2.5  ...  M Dean     4  3.25   2.2      3    3.4    2.3    2.7
# freq      899  ...     327    76   285    84    936   5044    801   1096
#
#           WHD    WHH
# count   23698  23698
# unique    202    357
# top       3.2    2.5
# freq     4238   1156
#
# [4 rows x 68 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23737 entries, 0 to 23736
# Data columns (total 68 columns):
# AC          23679 non-null object
# AF          23700 non-null object
# AR          23685 non-null object
# AS          23702 non-null object
# AST         23702 non-null object
# AY          23679 non-null object
# AwayTeam    23703 non-null object
# B365A       23681 non-null object
# B365D       23681 non-null object
# B365H       23686 non-null object
# BWA         23633 non-null object
# BWD         23633 non-null object
# BWH         23648 non-null object
# Bb1X2       23703 non-null object
# BbAH        23698 non-null object
# BbAHh       22044 non-null object
# BbAv<2.5    23698 non-null object
# BbAv>2.5    23703 non-null object
# BbAvA       23703 non-null object
# BbAvAHA     22044 non-null object
# BbAvAHH     22044 non-null object
# BbAvD       23703 non-null object
# BbAvH       23703 non-null object
# BbMx<2.5    23698 non-null object
# ...

# %%
df.isnull().sum()
# Out:
# AC             58
# AF             37
# AR             52
# AS             35
# AST            35
# AY             58
# AwayTeam       34
# B365A          56
# B365D          56
# B365H          51
# BWA           104
# BWD           104
# BWH            89
# Bb1X2          34
# BbAH           39
# BbAHh        1693
# BbAv<2.5       39
# BbAv>2.5       34
# BbAvA          34
# BbAvAHA      1693
# BbAvAHH      1693
# BbAvD          34
# BbAvH          34
# BbMx<2.5       39
# BbMx>2.5       34
# BbMxA          34
# BbMxAHA      1693
# BbMxAHH      1693
# BbMxD          34
# BbMxH          34
#             ...
# HR             52
# HS             35
# HST            35
# HTAG           35
# HTHG           35
# HTR            35
# HY             58
# HomeTeam       34
# IWA            90
# IWD            90
# IWH           127
# LBA          2617
# LBD          2617
# LBH          2616
# PSA            47
# PSCA         1716
# PSCD         1716
# PSCH         1716
# PSD            47
# ...

# %%
#visualize
sns.heatmap(df.isnull(), cbar=False)

# %%
import missingno as msno
plt.figure(figsize=(10, 16))
msno.heatmap(df)

# %%
msno.matrix(df)

# %%
# drop the betting odds data too many missing values

# %%
#df.drop(['BbMxAHA','BbAHh ','BbAvAHH ','BbAvAHA','BbMxAHA','LBA ','LBD','LBH','PSCA','PSCD ','PSCH','SJH','SJD ','SJA']
        #|inplace=True,axis=1)

# %%
df.drop('PSCH',inplace=True,axis=1)

# %%
df.drop('BbAHh',inplace=True,axis=1)

# %%
df.drop(['BbAvAHA','BbAvAHH','SJA','SJD','SJH','PSCD','PSCA','BbMxAHA','BbMxAHH'],inplace=True,axis=1)

# %%
df.drop(['LBA','LBD','LBH'],inplace=True,axis=1)

# %%
df.isnull().sum()
# Out:
# AC           58
# AF           37
# AR           52
# AS           35
# AST          35
# AY           58
# AwayTeam     34
# B365A        56
# B365D        56
# B365H        51
# BWA         104
# BWD         104
# BWH          89
# Bb1X2        34
# BbAH         39
# BbAv<2.5     39
# BbAv>2.5     34
# BbAvA        34
# BbAvD        34
# BbAvH        34
# BbMx<2.5     39
# BbMx>2.5     34
# BbMxA        34
# BbMxD        34
# BbMxH        34
# BbOU         34
# Date         34
# Div          34
# FTAG         34
# FTHG         34
# FTR          34
# HC           35
# HF           37
# HR           52
# HS           35
# HST          35
# HTAG         35
# HTHG         35
# HTR          35
# HY           58
# HomeTeam     34
# IWA          90
# IWD          90
# IWH         127
# PSA          47
# PSD          47
# PSH          48
# Referee      41
# VCA          34
# VCD          34
# VCH          34
# WHA          39
# WHD          39
# WHH          39
# dtype: int64

# %%
df.shape
# Out:
# (23737, 54)

# %%
df.dtypes
# Out:
# AC          object
# AF          object
# AR          object
# AS          object
# AST         object
# AY          object
# AwayTeam    object
# B365A       object
# B365D       object
# B365H       object
# BWA         object
# BWD         object
# BWH         object
# Bb1X2       object
# BbAH        object
# BbAv<2.5    object
# BbAv>2.5    object
# BbAvA       object
# BbAvD       object
# BbAvH       object
# BbMx<2.5    object
# BbMx>2.5    object
# BbMxA       object
# BbMxD       object
# BbMxH       object
# BbOU        object
# Date        object
# Div         object
# FTAG        object
# FTHG        object
# FTR         object
# HC          object
# HF          object
# HR          object
# HS          object
# HST         object
# HTAG        object
# HTHG        object
# HTR         object
# HY          object
# HomeTeam    object
# IWA         object
# IWD         object
# IWH         object
# PSA         object
# PSD         object
# PSH         object
# ...

# %%
df.tail()
# Out:
#         AC   AF    AR AS AST   AY        AwayTeam B365A B365D  B365H  ...  \
# 23732  NaN  3.4  3.25  1   0  NaN          Barnet   NaN   NaN    2.2  ...
# 23733  NaN  6.5     6  2   0  NaN  Braintree Town   NaN   NaN  11.75  ...
# 23734  NaN  3.3   3.2  0   0  NaN    Chesterfield   NaN   NaN   2.45  ...
# 23735  NaN  3.4   3.3  0   0  NaN       Aldershot   NaN   NaN    2.4  ...
# 23736  NaN  3.3   3.2  1   0  NaN       Harrogate   NaN   NaN   3.35  ...
#
#         PSA PSD  PSH    Referee VCA    VCD    VCH   WHA   WHD   WHH
# 23732   3.4  26  2.2     L Wood  22    2.2    2.3  3.33   3.5  3.04
# 23733  1.25  28   12   Jj Smith  23  12.33  14.25  6.21     7  1.19
# 23734  2.85  28  2.5     D Rock  23   2.45    2.6  3.24  3.45   2.7
# 23735   2.8  28  2.5  S Purkiss  23   2.45    2.6  3.32   3.5  2.64
# 23736  2.15  28  3.5     J Hull  23   3.39   3.65  3.24   3.4  2.08
#
# [5 rows x 54 columns]

# %%
df.columns
# Out:
# Index(['AC', 'AF', 'AR', 'AS', 'AST', 'AY', 'AwayTeam', 'B365A', 'B365D',
#        'B365H', 'BWA', 'BWD', 'BWH', 'Bb1X2', 'BbAH', 'BbAv<2.5', 'BbAv>2.5',
#        'BbAvA', 'BbAvD', 'BbAvH', 'BbMx<2.5', 'BbMx>2.5', 'BbMxA', 'BbMxD',
#        'BbMxH', 'BbOU', 'Date', 'Div', 'FTAG', 'FTHG', 'FTR', 'HC', 'HF', 'HR',
#        'HS', 'HST', 'HTAG', 'HTHG', 'HTR', 'HY', 'HomeTeam', 'IWA', 'IWD',
#        'IWH', 'PSA', 'PSD', 'PSH', 'Referee', 'VCA', 'VCD', 'VCH', 'WHA',
#        'WHD', 'WHH'],
#       dtype='object')

# %%
#sns.heatmap(df.corr())

# %%
df_cols=['HomeTeam','AwayTeam', 'Referee','AC', 'AF', 'AR', 'AS', 'AST', 'AY',  'B365A', 'B365D',
       'B365H', 'BWA', 'BWD', 'BWH', 'Bb1X2', 'BbAH', 'BbAv<2.5', 'BbAv>2.5',
       'BbAvA', 'BbAvD', 'BbAvH', 'BbMx<2.5', 'BbMx>2.5', 'BbMxA', 'BbMxD',
       'BbMxH', 'BbOU', 'Date', 'Div', 'FTAG', 'FTHG', 'FTR', 'HC', 'HF', 'HR',
       'HS', 'HST', 'HTAG', 'HTHG', 'HTR', 'HY', 'IWA', 'IWD',
       'IWH', 'PSA', 'PSD', 'PSH', 'VCA', 'VCD', 'VCH', 'WHA',
       'WHD', 'WHH']

# %%
df = df.reindex(columns=df_cols)

# %%
df.head()
# Out:
#      HomeTeam        AwayTeam   Referee AC  AF AR  AS AST AY B365A  ...   IWH  \
# 0     Arsenal  Crystal Palace    J Moss  3  19  1   4   2  2    15  ...   1.3
# 1   Leicester         Everton   M Jones  6  10  0  13   3  1   2.4  ...   2.9
# 2  Man United         Swansea    M Dean  0  20  0   5   4  4    11  ...  1.33
# 3         QPR            Hull  C Pawson  9  10  0  11   4  2   3.1  ...   2.3
# 4       Stoke     Aston Villa  A Taylor  8   9  0   7   2  3   4.5  ...     2
#
#      PSA   PSD   PSH   VCA   VCD   VCH  WHA  WHD   WHH
# 0  14.01  6.45  1.26  10.5  6.25  1.25   12  5.5  1.25
# 1   2.46  3.38  3.14   2.4   3.4   3.2  2.4  3.1   3.1
# 2   10.6   5.1  1.37    10   5.2  1.36    9  4.5  1.36
# 3   3.22  3.26  2.48  3.12   3.2  2.55  2.9    3   2.6
# 4   4.55  3.47  1.95  4.75   3.3  1.95  4.2  3.2  1.95
#
# [5 rows x 54 columns]

# %% [markdown]
# * Is the referee important to the performance of a team

# %% [markdown]
# ### Referee Bias
# * There is overwhelming evidence that referees decisions are biased towards the home team. Moskowitz and Wertheim (2012) found that the referee was the most influential factor on home advantage, and that home teams gained a small bias from the referee. They did make it clear that this is not done consciously, instead, the referees were affected subconsciously by the emotion of a home crowd. *
#
# * A study by Harvard Research Assistant Ryan Boyko on 5,000 Premier League games from 1992 to 2006 found for every 10,000 home team fans, home advantage increased by 0.1 goals. It also highlighted that inexperienced referees were more than likely to award penalties to the home team. *
#
# * Between 1992 and 2014, penalties in the Premier League have led to goals 85% of the time - of these 1,666 penalties, 63% were awarded to the home team. Therefore bettors should profile referees when building a betting model to identify value. *
#
# ##### src~ https://help.smarkets.com/hc/en-gb/articles/115000647291-Why-you-should-consider-home-advantage-for-football-trading

# %%
df[ 'Referee'].nunique()
# Out:
# 182

# %%
df[ 'Referee'].isnull().sum()
# Out:
# 41

# %%
df2 = df.drop(['HomeTeam','AwayTeam','Referee'],axis=1)

# %%
df2.head()
# Out:
#   AC  AF AR  AS AST AY B365A B365D B365H   BWA  ...   IWH    PSA   PSD   PSH  \
# 0  3  19  1   4   2  2    15   6.5  1.25    12  ...   1.3  14.01  6.45  1.26
# 1  6  10  0  13   3  1   2.4   3.4   3.2   2.4  ...   2.9   2.46  3.38  3.14
# 2  0  20  0   5   4  4    11     5  1.36     9  ...  1.33   10.6   5.1  1.37
# 3  9  10  0  11   4  2   3.1   3.3   2.5  2.85  ...   2.3   3.22  3.26  2.48
# 4  8   9  0   7   2  3   4.5   3.5  1.95   3.9  ...     2   4.55  3.47  1.95
#
#     VCA   VCD   VCH  WHA  WHD   WHH
# 0  10.5  6.25  1.25   12  5.5  1.25
# 1   2.4   3.4   3.2  2.4  3.1   3.1
# 2    10   5.2  1.36    9  4.5  1.36
# 3  3.12   3.2  2.55  2.9    3   2.6
# 4  4.75   3.3  1.95  4.2  3.2  1.95
#
# [5 rows x 51 columns]

# %%
#lets convert all the dtypes to continuos numerical

# %%
char_cols = df2.dtypes.pipe(lambda x: x[x == 'object']).index

for c in char_cols:
    df2[c] = pd.factorize(df2[c])[0]

# %%
df2.shape
# Out:
# (23737, 51)

# %%
df = df[['HomeTeam','AwayTeam','Referee']]

# %%
df.shape
# Out:
# (23737, 3)

# %%
#should i concat them
#do i create an app that takes a team name and generates its number according to encoding
#i will
#flask interface

# %%
df['HomeTeam'].nunique()
# Out:
# 131
